# %%
# %cd "/Users/hibasameen/Dropbox/RTT Wait Time ETL/rtt_etl_pipeline_offline"
# !ls
# Out:
# /Users/hibasameen/Dropbox/RTT Wait Time ETL/rtt_etl_pipeline_offline
# airflow_dags     README.md        src
# Dockerfile       requirements.txt

# %%
import sys

# !{sys.executable} -m src.rtt_etl \
  --out data \
  --start-fy 2014 \
  --end-fy 2018 \
  --dataset provider_trust_all
# Out:
# == FY 2014-15: scraping https://www.england.nhs.uk/statistics/statistical-work-areas/rtt-waiting-times/rtt-data-2014-15/
# ...
# Converting (LibreOffice): Incomplete-Provider-Mar15-revised-XLS-3691K.xls
# ...
# Converting (LibreOffice): Incomplete-Provider-Feb15-revised-XLS-3681K.xls
# ...
# Converting (LibreOffice): Incomplete-Provider-Jan15-revised-XLS-3708K.xls
# ...
# Converting (LibreOffice): Incomplete-Provider-Dec14-revised-XLS-3690K.xls
# ...
# Converting (LibreOffice): Incomplete-Provider-Nov14-revised-XLS-3690K.xls
# ...
# Converting (LibreOffice): Incomplete-Provider-Oct14-XLS-3690K-03680.xls
# ...
# Converting (LibreOffice): Incomplete-Provider-Sep14-revised-XLS-3746K.xls
# ...
# Converting (LibreOffice): Incomplete-Provider-Aug14-revised-XLS-3719K.xls
# ...
# Converting (LibreOffice): Incomplete-Provider-Jul14-revised-2-XLS-3728K.xls
# ...
# Converting (LibreOffice): Incomplete-Provider-Jun14-revised-XLS-3746K.xls
# ...
# Converting (LibreOffice): Incomplete-Provider-May14-revised-XLS-3756K.xls
# ...

# %%
import sys

# !{sys.executable} -u -m src.rtt_etl \
  --out "/Users/hibasameen/Dropbox/RTT Wait Time ETL/rtt_etl_data" \
  --start-fy 2014 \
  --end-fy 2025 \
  --dataset provider_trust_all \
  --verbose-download
# Out:
# == Using output directory: /Users/hibasameen/Dropbox/RTT Wait Time ETL/rtt_etl_data
# == Found existing source files under bronze/: 487
# == Existing source files under bronze: 487
# == FY 2014-15: scraping https://www.england.nhs.uk/statistics/statistical-work-areas/rtt-waiting-times/rtt-data-2014-15/
# Skipping (already downloaded): Incomplete-Provider-Mar15-revised-XLS-3691K.xls
# Skipping (already downloaded): Incomplete-Provider-Feb15-revised-XLS-3681K.xls
# Skipping (already downloaded): Incomplete-Provider-Jan15-revised-XLS-3708K.xls
# Skipping (already downloaded): Incomplete-Provider-Dec14-revised-XLS-3690K.xls
# Skipping (already downloaded): Incomplete-Provider-Nov14-revised-XLS-3690K.xls
# Skipping (already downloaded): Incomplete-Provider-Oct14-XLS-3690K-03680.xls
# Skipping (already downloaded): Incomplete-Provider-Sep14-revised-XLS-3746K.xls
# Skipping (already downloaded): Incomplete-Provider-Aug14-revised-XLS-3719K.xls
# ...
